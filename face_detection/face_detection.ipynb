# %%
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread(r'C:\Users\Acer\face_detection\images\face_detection.jpg')

# %%
image.shape
# Out:
# (750, 1000, 3)

# %%
plt.imshow(image)
plt.show()

# %%
image = cv2.resize(image, (600, 400))
image.shape
# Out:
# (400, 600, 3)

# %%
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)
plt.show()

# %%
image.shape
# Out:
# (400, 600, 3)

# %%
image_gray.shape
# Out:
# (400, 600)

# %%
face_detector = cv2.CascadeClassifier(r'C:\Users\Acer\face_detection\haarcascade_frontalface_default.xml')

# %%
detections = face_detector.detectMultiScale(image_gray)

# %%
detections
# Out:
# array([[214, 113,  31,  31],
#        [352, 116,  29,  29],
#        [283, 126,  26,  26],
#        [405, 125,  31,  31],
#        [104, 189,  41,  41]])

# %%
len(detections)
# Out:
# 5

# %%
for (x, y, w, h) in detections:
  #print(x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
plt.imshow(image)
plt.show()

# %%
image = cv2.imread(r'C:\Users\Acer\face_detection\images\face_detection.jpg')
image = cv2.resize(image, (500, 400))
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.05)
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
plt.imshow(image)

# %%
image = cv2.imread(r'C:\Users\Acer\face_detection\images\face_detection.jpg')
detections = face_detector.detectMultiScale(image_gray, scaleFactor=1.2, minNeighbors=7,
                                            minSize=(400,200), maxSize=(800,600))
for (x, y, w, h) in detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 4)
plt.imshow(image)
plt.show()

# %%
eye_detector = cv2.CascadeClassifier(r'C:\Users\Acer\face_detection\haarcascade_eye.xml')

# %%
image = cv2.imread(r'C:\Users\Acer\face_detection\images\face_detection.jpg')
#image = cv2.resize(image, (800, 600))
print(image.shape)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face_detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image_gray, scaleFactor = 1.1, minNeighbors=10, maxSize=(70,70))
for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)

plt.imshow(image)
# Out:
# (750, 1000, 3)

# %%
car_detector = cv2.CascadeClassifier(r'C:\Users\Acer\face_detection\cars.xml')
image = cv2.imread(r'C:\Users\Acer\face_detection\images\mobil.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=5)
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()
